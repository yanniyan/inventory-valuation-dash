# %%
import pandas as pd

df = pd.read_csv("./data/inventory_valuation.csv")
df.tail()
# Out:
#            month               sku variation  category    location  \
# 6523  2025-11-01  pineapple_ginger      plus  beverage  in_transit
# 6524  2025-12-01  pineapple_ginger      plus  beverage  in_transit
# 6525  2026-01-01  pineapple_ginger      plus  beverage  in_transit
# 6526  2026-02-01  pineapple_ginger      plus  beverage  in_transit
# 6527  2026-03-01  pineapple_ginger      plus  beverage  in_transit
#
#       inventory_units  unit_cost  inventory_value
# 6523              204         12             2448
# 6524              225         12             2700
# 6525              189         12             2268
# 6526              219         12             2628
# 6527              225         12             2700
